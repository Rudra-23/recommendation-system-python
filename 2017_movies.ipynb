# %%
import requests
from bs4 import BeautifulSoup
import string


def gethtml(url):
    r = requests.get(url).text
    return r

# %%
getdata = gethtml('https://www.imdb.com/list/ls058982125/?sort=moviemeter,asc&st_dt=&mode=detail&page=1')
soup = BeautifulSoup(getdata, "html.parser")

# %%
x=soup.findAll("div", {"class": "lister-item mode-detail"})

# %%
import re
movie=[]
pattern =re.compile(r'/title/.+')
for link in x:
  a =link.findAll('a')
  for l in a:
    if pattern.search(l['href']):
      if l.string != None:
          movie.append([l.string])

# %%
len(movie)
# Out:
# 100

# %%
len(movie)
# Out:
# 100

# %%
movie
# Out:
# [['Kingsman: The Golden Circle'],
#  ['Blade Runner 2049'],
#  ['Dunkirk'],
#  ['Thor: Ragnarok'],
#  ['It'],
#  ['Beauty and the Beast'],
#  ['Justice League'],
#  ['Get Out'],
#  ['Jumanji: Welcome to the Jungle'],
#  ['Good Time'],
#  ['Spider-Man: Homecoming'],
#  ['Guardians of the Galaxy Vol. 2'],
#  ['All the Money in the World'],
#  ['Baby Driver'],
#  ['Jungle'],
#  ['Wonder Woman'],
#  ['Logan Lucky'],
#  ['Logan'],
#  ['Valerian and the City of a Thousand Planets'],
#  ['Pirates of the Caribbean: Dead Men Tell No Tales'],
#  ['Alien: Covenant'],
#  ['Coco'],
#  ["Molly's Game"],
#  ['Baywatch'],
#  ['Marshall'],
#  ['Star Wars: Episode VIII - The Last Jedi'],
#  ['Pitch Perfect 3'],
#  ['Mother!'],
#  ['Kong: Skull Island'],
#  ['The Fate of the Furious'],
#  ['The Mummy'],
#  ['Transformers: The Last Knight'],
#  ['The Dark Tower'],
#  ['Life'],
#  ['John Wick: Chapter 2'],
#  ['I, Tonya'],
#  ['Fifty Shades Darker'],
#  ['Wind River'],
#  ['Power Rangers'],
# ...

# %%
sx=soup.findAll("span", {"class": "genre"})
gen =[]
for span in sx:
  gen.append([span.text.strip()])

# %%
len(gen)
# Out:
# 100

# %%
gen
# Out:
# [['Action, Adventure, Comedy'],
#  ['Action, Drama, Mystery'],
#  ['Action, Drama, History'],
#  ['Action, Adventure, Comedy'],
#  ['Horror'],
#  ['Family, Fantasy, Musical'],
#  ['Action, Adventure, Fantasy'],
#  ['Horror, Mystery, Thriller'],
#  ['Action, Adventure, Comedy'],
#  ['Crime, Drama, Thriller'],
#  ['Action, Adventure, Sci-Fi'],
#  ['Action, Adventure, Comedy'],
#  ['Biography, Crime, Drama'],
#  ['Action, Crime, Music'],
#  ['Action, Adventure, Biography'],
#  ['Action, Adventure, Fantasy'],
#  ['Comedy, Crime, Drama'],
#  ['Action, Drama, Sci-Fi'],
#  ['Action, Adventure, Fantasy'],
#  ['Action, Adventure, Fantasy'],
#  ['Horror, Sci-Fi, Thriller'],
#  ['Animation, Adventure, Family'],
#  ['Biography, Crime, Drama'],
#  ['Action, Comedy, Crime'],
#  ['Biography, Crime, Drama'],
#  ['Action, Adventure, Fantasy'],
#  ['Comedy, Music'],
#  ['Drama, Horror, Mystery'],
#  ['Action, Adventure, Fantasy'],
#  ['Action, Adventure, Crime'],
#  ['Action, Adventure, Fantasy'],
# ...

# %%
over=soup.findAll("p", {"class": ""})

# %%
overview=[]
import re 
pattern =re.compile(r'Watched. Ra.+')
for para in over:
  if not pattern.search(para.text):
    overview.append([para.text.strip()])

# %%
overview
# Out:
# [["After the Kingsman's headquarters are destroyed and the world is held hostage, an allied spy organisation in the United States is discovered. These two elite secret organisations must band together to defeat a common enemy."],
#  ["Young Blade Runner K's discovery of a long-buried secret leads him to track down former Blade Runner Rick Deckard, who's been missing for thirty years."],
#  ['Allied soldiers from Belgium, the British Empire, and France are surrounded by the German Army and evacuated during a fierce battle in World War II.'],
#  ['Imprisoned on the planet Sakaar, Thor must race against time to return to Asgard and stop Ragnarök, the destruction of his world, at the hands of the powerful and ruthless villain Hela.'],
#  ['In the summer of 1989, a group of bullied kids band together to destroy a shape-shifting monster, which disguises itself as a clown and preys on the children of Derry, their small Maine town.'],
# ...

# %%
len(overview)
# Out:
# 100

# %%
x=soup.findAll("div", {"class": "lister-item mode-detail"})

crew =[]
for div in x:
  p =div.findAll('p',{'class':'text-muted text-small'})
  temp =[]
  link =p[1].findAll('a')
  for final in link:
    #print(final)
    temp.append(final.text)
  #print(temp)
  crew.append(temp)

# %%
crew
# Out:
# [['Matthew Vaughn',
#   'Taron Egerton',
#   'Colin Firth',
#   'Mark Strong',
#   'Channing Tatum'],
#  ['Denis Villeneuve',
#   'Harrison Ford',
#   'Ryan Gosling',
#   'Ana de Armas',
#   'Dave Bautista'],
#  ['Christopher Nolan',
#   'Fionn Whitehead',
#   'Barry Keoghan',
#   'Mark Rylance',
#   'Tom Hardy'],
#  ['Taika Waititi',
#   'Chris Hemsworth',
#   'Tom Hiddleston',
#   'Cate Blanchett',
#   'Mark Ruffalo'],
#  ['Andy Muschietti',
#   'Bill Skarsgård',
#   'Jaeden Martell',
#   'Finn Wolfhard',
#   'Sophia Lillis'],
#  ['Bill Condon', 'Emma Watson', 'Dan Stevens', 'Luke Evans', 'Josh Gad'],
#  ['Zack Snyder', 'Ben Affleck', 'Gal Gadot', 'Jason Momoa', 'Ezra Miller'],
#  ['Jordan Peele',
#   'Daniel Kaluuya',
#   'Allison Williams',
#   'Bradley Whitford',
#   'Catherine Keener'],
#  ['Jake Kasdan', 'Dwayne Johnson', 'Karen Gillan', 'Kevin Hart', 'Jack Black'],
#  ['Benny Safdie',
#   'Josh Safdie',
#   'Robert Pattinson',
#   'Benny Safdie',
#   'Jennifer Jason Leigh',
# ...

# %%
len(crew)
# Out:
# 100

# %%
movie_x=[]
for m in movie:
  movie_x.append(m[0])

# %%
gen_x=[]
for g in gen:
  gen_x.append(g[0])

# %%
over_x =[]
for over in overview:
  over_x.append(over[0])

# %%
dir_x=[]
cast_x=[]
for c in crew:
  dir_x.append(c[0])
  cast_x.append(" ".join(c[1:]))

# %%
struct ={'title':movie_x,'genre':gen_x,'overview':over_x,'cast':cast_x,'director':dir_x,'lang':['en']*100,'comp':['unknown']*100}

# %%
df =pd.DataFrame(data=struct)

# %%
df.head(50)
# Out:
#                                                title  ...     comp
# 0                        Kingsman: The Golden Circle  ...  unknown
# 1                                  Blade Runner 2049  ...  unknown
# 2                                            Dunkirk  ...  unknown
# 3                                     Thor: Ragnarok  ...  unknown
# 4                                                 It  ...  unknown
# 5                               Beauty and the Beast  ...  unknown
# 6                                     Justice League  ...  unknown
# 7                                            Get Out  ...  unknown
# 8                     Jumanji: Welcome to the Jungle  ...  unknown
# 9                                          Good Time  ...  unknown
# 10                            Spider-Man: Homecoming  ...  unknown
# 11                    Guardians of the Galaxy Vol. 2  ...  unknown
# 12                        All the Money in the World  ...  unknown
# ...

# %%
df.to_csv('Dataset/2017m1.csv')
